# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import os
from typing import List, Tuple, Dict
import pandas as pd
import numpy as np

import osmnx as ox
import networkx as nx
import folium
from geopy.geocoders import Nominatim
from geopy.distance import geodesic
from shapely.geometry import Point

from dotenv import load_dotenv

load_dotenv('../.env')
# print("PYTHONPATH:", os.environ.get('PYTHONPATH'))

import geo_utils
df = pd.read_csv('../data/lokationen-geodaten.csv')

# %%
df = df.rename(columns={' "lat"': 'lat', ' "lng"': 'long', ' "Ort"': 'Ort', ' "ID"': 'ID'})
df['lat'] = df['lat'].str.strip().str.replace('"', '', regex=False).replace('', np.nan).astype(float)
df['long'] = df['long'].str.strip().str.replace('"', '', regex=False).replace('', np.nan).astype(float)
df.head(5)
# geo_utils.get_locations_within_range(center_long: float, center_lat: float, n: float, df: pd.DataFrame)
# Out:
#            Bezeichnung      long        lat         Ort  \
# 0      Besitos Münster  7.632360  51.962471   "Münster"
# 1      Bistro GreenBee  9.079920  52.187170   "Rinteln"
# 2    Bodega Beach Club  9.080265  52.190996   "Rinteln"
# 3  Bodega Marktplatz 9  9.081009  52.187531   "Rinteln"
# 4        Bodega Verden  9.231492  52.921643    "Verden"
#
#                                         ID
# 0   "20b68cc5-c5c1-41ee-8518-b20973171c25"
# 1                  "G2z0yxF76474q2z1EsRxj"
# 2                   "rJ3eg2BbsmMS427SkpnH"
# 3                   "qaZycWKmyxiBbyE8XvLd"
# 4                  "bk5y74SLJ7CdWpIXdxJzN"

# %%
df = df.dropna(subset=['lat', 'long']).reset_index(drop=True)

# %%
searchers = [
    (53.0, 9.17, "Test Verden"),
    (52.425435999, 9.424194999, "Test Wunstorf"),
    (52.32010, 9.20780, "Test Stadthagen"),
    (52.2116, 8.8087, "Test Bad Oeynhausen"),
    (52.02830, 7.11400, "Test Münster"),
    (52.18698, 9.07984, 'Test Rinteln')
]

# %%
# Show total map
geo_utils.plot_points_on_map(df, searchers=searchers)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_574b4dbc3bb02b5329005fb6337fbff3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_574b4dbc3bb02b5329005fb6337fbff3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_574b4dbc3bb02b5329005fb6337fbff3 = L.map(
#                 &quot;map_574b4dbc3bb02b5329005fb6337fbff3&quot;,
#                 {
#                     center: [52.40011756315789, 8.711955355263157],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 9,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d0b6e4975dde52f7607c3d7c88adf453 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d0b6e4975dde52f7607c3d7c88adf453.addTo(map_574b4dbc3bb02b5329005fb6337fbff3);
#
#
#             var marker_86df4b0e8bd30596c4ea61b5961ff1ba = L.marker(
#                 [51.9624708, 7.6323599],
#                 {
# }
#             ).addTo(map_574b4dbc3bb02b5329005fb6337fbff3);
#
#
#             var icon_672a02014c0034c097f9261eaf217aa7 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_86df4b0e8bd30596c4ea61b5961ff1ba.setIcon(icon_672a02014c0034c097f9261eaf217aa7);
#
#
#         var popup_f7e9e340bb8dc7628a5da0057c036f3a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_80788dfdca1ddca69c1f92c100d53fc2 = $(`&lt;div id=&quot;html_80788dfdca1ddca69c1f92c100d53fc2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Besitos Münster&lt;/div&gt;`)[0];
#                 popup_f7e9e340bb8dc7628a5da0057c036f3a.setContent(html_80788dfdca1ddca69c1f92c100d53fc2);
#
#
#
#         marker_86df4b0e8bd30596c4ea61b5961ff1ba.bindPopup(popup_f7e9e340bb8dc7628a5da0057c036f3a)
#         ;
#
#
#
#
#             marker_86df4b0e8bd30596c4ea61b5961ff1ba.bindTooltip(
#                 `&lt;div&gt;
#                      Besitos Münster
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_bb4ab170deaa2d2273f57950365d8a83 = L.marker(
#                 [52.18716999999999, 9.07992],
#                 {
# }
#             ).addTo(map_574b4dbc3bb02b5329005fb6337fbff3);
#
#
#             var icon_636b55267eea7b30f45a8c2e502f99e1 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_bb4ab170deaa2d2273f57950365d8a83.setIcon(icon_636b55267eea7b30f45a8c2e502f99e1);
#
#
#         var popup_723b883a581d9bb581e27e83d8780ac9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_807106dede92f08e91fe482a2565a419 = $(`&lt;div id=&quot;html_807106dede92f08e91fe482a2565a419&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bistro GreenBee&lt;/div&gt;`)[0];
#                 popup_723b883a581d9bb581e27e83d8780ac9.setContent(html_807106dede92f08e91fe482a2565a419);
#
#
#
#         marker_bb4ab170deaa2d2273f57950365d8a83.bindPopup(popup_723b883a581d9bb581e27e83d8780ac9)
#         ;
#
#
#
#
#             marker_bb4ab170deaa2d2273f57950365d8a83.bindTooltip(
#                 `&lt;div&gt;
#                      Bistro GreenBee
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_c6f47d3257a7180164e9a1a0b7616811 = L.marker(
#                 [52.1909962, 9.080264999999999],
#                 {
# }
#             ).addTo(map_574b4dbc3bb02b5329005fb6337fbff3);
#
#
#             var icon_32ba29cae0e8721aa929c99c4d2701cb = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_c6f47d3257a7180164e9a1a0b7616811.setIcon(icon_32ba29cae0e8721aa929c99c4d2701cb);
#
#
#         var popup_9b2c2fd19fe98f990b91c9da050a6e86 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d51e819487e0538b4fa7f824a23a5db1 = $(`&lt;div id=&quot;html_d51e819487e0538b4fa7f824a23a5db1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bodega Beach Club&lt;/div&gt;`)[0];
#                 popup_9b2c2fd19fe98f990b91c9da050a6e86.setContent(html_d51e819487e0538

# %%
searcher = searchers[1]
near_by_search_result = geo_utils.get_locations_within_range(lat=searcher[0], long=searcher[1], n=300, df=df)
geo_utils.plot_points_on_map(near_by_search_result, searchers=[searcher])
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_246c3047c15ebdcdf7d74e295720a5f4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_246c3047c15ebdcdf7d74e295720a5f4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_246c3047c15ebdcdf7d74e295720a5f4 = L.map(
#                 &quot;map_246c3047c15ebdcdf7d74e295720a5f4&quot;,
#                 {
#                     center: [52.40011756315789, 8.711955355263157],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 9,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_07aaad33573f417a00ad101284dcadc7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_07aaad33573f417a00ad101284dcadc7.addTo(map_246c3047c15ebdcdf7d74e295720a5f4);
#
#
#             var marker_1af929c2c8d791b933c7a071fb12c960 = L.marker(
#                 [52.4237627, 9.443686999999999],
#                 {
# }
#             ).addTo(map_246c3047c15ebdcdf7d74e295720a5f4);
#
#
#             var icon_0bf87a33cd8383fb119fe58d361a8fcb = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_1af929c2c8d791b933c7a071fb12c960.setIcon(icon_0bf87a33cd8383fb119fe58d361a8fcb);
#
#
#         var popup_3936b3fc0c81422abe5dd207b3548d9e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6cd63bf99573531da0f5181fe904ab60 = $(`&lt;div id=&quot;html_6cd63bf99573531da0f5181fe904ab60&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;fresh &amp; joy&lt;/div&gt;`)[0];
#                 popup_3936b3fc0c81422abe5dd207b3548d9e.setContent(html_6cd63bf99573531da0f5181fe904ab60);
#
#
#
#         marker_1af929c2c8d791b933c7a071fb12c960.bindPopup(popup_3936b3fc0c81422abe5dd207b3548d9e)
#         ;
#
#
#
#
#             marker_1af929c2c8d791b933c7a071fb12c960.bindTooltip(
#                 `&lt;div&gt;
#                      fresh &amp; joy - 1.34 km
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_12e8ed1382288e65051703334efe7c45 = L.marker(
#                 [52.3358082, 9.3776432],
#                 {
# }
#             ).addTo(map_246c3047c15ebdcdf7d74e295720a5f4);
#
#
#             var icon_09db5ce7de2fa1fa16d1332614535041 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_12e8ed1382288e65051703334efe7c45.setIcon(icon_09db5ce7de2fa1fa16d1332614535041);
#
#
#         var popup_90ffca74da23a3a51b6fc5441c4a3e97 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ca67cbda1c0cf5bf48dadf80abbe4979 = $(`&lt;div id=&quot;html_ca67cbda1c0cf5bf48dadf80abbe4979&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ESScoBAR&lt;/div&gt;`)[0];
#                 popup_90ffca74da23a3a51b6fc5441c4a3e97.setContent(html_ca67cbda1c0cf5bf48dadf80abbe4979);
#
#
#
#         marker_12e8ed1382288e65051703334efe7c45.bindPopup(popup_90ffca74da23a3a51b6fc5441c4a3e97)
#         ;
#
#
#
#
#             marker_12e8ed1382288e65051703334efe7c45.bindTooltip(
#                 `&lt;div&gt;
#                      ESScoBAR - 10.46 km
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_25fd952141ad625bbe38868da4d49c52 = L.marker(
#                 [52.3126257, 9.360021099999999],
#                 {
# }
#             ).addTo(map_246c3047c15ebdcdf7d74e295720a5f4);
#
#
#             var icon_97b7f190824062d8fc1882b79065bd0f = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_25fd952141ad625bbe38868da4d49c52.setIcon(icon_97b7f190824062d8fc1882b79065bd0f);
#
#
#         var popup_fabcd77229e2656273bcd753e5a7f93b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0cf87541b3e4e8ab05c28598e0c0dd5c = $(`&lt;div id=&quot;html_0cf87541b3e4e8ab05c28598e0c0dd5c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;TOBO POS - DEMO&lt;/div&gt;`)[0];
#                 popup_fabcd77229e2656273bcd753e5a7f93b.setContent(html_0cf8754

# %%
class DeliveryRouter:
    def __init__(self, city: str = "Berlin, Germany"):
        """Initialize the router with a specific city's road network."""
        # Initialize Nominatim geocoder
        self.geocoder = Nominatim(user_agent="delivery_router_rinteln", timeout=6)
        self.city_boundary = ox.geocode_to_gdf(city)

        # Download and create the road network for the specified city
        self.G = ox.graph_from_place(city, network_type="drive", simplify=False)
        
        # Convert to projected graph for accurate distance calculations; UTM zone 32N
        self.G_proj = ox.project_graph(self.G, to_crs="EPSG:25832")
        
        # Store restaurants data
        self.restaurants = {}
        self.load_all_restaurants()
        
    def load_all_restaurants(self):
        """Load all restaurants from OpenStreetMap within the city boundary."""
        # Define tags for restaurants and similar establishments
        tags = {
            'amenity': ['restaurant', 'cafe', 'fast_food', 'bar', 'pub'],
            'cuisine': True  # This will get all cuisine types
        }
        
        # Get all POIs with these tags within the city boundary
        pois = ox.features_from_place("Rinteln, Germany", tags=tags)
        
        # Process each POI
        for idx, poi in pois.iterrows():
            name = poi.get('name', 'Unknown Restaurant')
            if name != 'Unknown Restaurant':  # Only add places with names
                try:
                    # Get coordinates
                    if isinstance(poi.geometry, Point):
                        lat, lon = poi.geometry.y, poi.geometry.x
                    else:
                        # For polygons, use centroid
                        lat, lon = poi.geometry.centroid.y, poi.geometry.centroid.x
                    
                    # Get address components if available
                    street = poi.get('addr:street', '')
                    housenumber = poi.get('addr:housenumber', '')
                    address = f"{street} {housenumber}, Rinteln" if street and housenumber else "Rinteln"
                    
                    # Store restaurant data
                    self.restaurants[name] = {
                        "address": address,
                        "lat": lat,
                        "lon": lon,
                        "node": ox.nearest_nodes(self.G, lon, lat),
                        "type": poi.get('amenity', 'unknown'),
                        "cuisine": poi.get('cuisine', 'unknown')
                    }
                    print(f"Added: {name} ({address})")
                except Exception as e:
                    print(f"Error adding {name}: {e}")

    def add_restaurant(self, name: str, address: str) -> bool:
        """Add a restaurant to the system with its location."""
        try:
            location = self.geocoder.geocode(f"{name}, {address}, Germany")
            if location:
                self.restaurants[name] = {
                    "address": address,
                    "lat": location.latitude,
                    "lon": location.longitude,
                    "node": ox.nearest_nodes(self.G, location.longitude, location.latitude)
                }
                return True
            return False
        except Exception as e:
            print(f"Error adding restaurant: {e}")
            return False
    
    def calculate_route_advanced(self, start_coords: Tuple[float, float], 
                        end_coords: Tuple[float, float]) -> List[Tuple[float, float]]:
        """Calculate a detailed route between two points."""
        start_node = ox.nearest_nodes(self.G, start_coords[1], start_coords[0])
        end_node = ox.nearest_nodes(self.G, end_coords[1], end_coords[0])
        
        # Find the shortest path by nodes
        path = nx.shortest_path(self.G, start_node, end_node, weight="length")
        
        # Retrieve the detailed geometry of the route
        route_coords = []
        for u, v in zip(path[:-1], path[1:]):  # Iterate over edges in the path
            edge_data = self.G[u][v][0]  # Get the edge data
            if "geometry" in edge_data:  # Use geometry if available
                route_coords.extend([(point[1], point[0]) for point in edge_data["geometry"].coords])
            else:  # Fall back to straight line if no geometry is present
                route_coords.extend([(self.G.nodes[u]['y'], self.G.nodes[u]['x']),
                                    (self.G.nodes[v]['y'], self.G.nodes[v]['x'])])
        
        return route_coords

    
    def visualize_map(self, driver_position: Tuple[float, float] = None, 
                     route: List[Tuple[float, float]] = None) -> folium.Map:
        """Create a visualization of restaurants, driver, and route."""
        # Create base map centered on Rinteln
        center_location = self.geocoder.geocode("Rinteln, Germany")
        m = folium.Map(location=[center_location.latitude, center_location.longitude], 
                      zoom_start=14)
        
        # Add restaurants with custom icons
        for name, data in self.restaurants.items():
            folium.Marker(
                [data["lat"], data["lon"]],
                popup=f"{name}\n{data['address']}",
                icon=folium.Icon(color='red', icon='cutlery')
            ).add_to(m)
        
        # Add driver position if provided
        if driver_position:
            folium.Marker(
                driver_position,
                popup="Driver Location",
                icon=folium.Icon(color='green', icon='user')
            ).add_to(m)
        
        # Add delivery route if provided
        if route:
            folium.PolyLine(
                route,
                weight=3,
                color='blue',
                opacity=0.8
            ).add_to(m)
        
        return m

    def get_estimated_delivery_time(self, route: List[Tuple[float, float]], 
                                  avg_speed_kmh: float = 30) -> float:
        """Calculate estimated delivery time in minutes for a route."""
        total_distance = 0
        for i in range(len(route) - 1):
            total_distance += geodesic(route[i], route[i + 1]).kilometers
        
        # Convert to hours and then to minutes
        return (total_distance / avg_speed_kmh) * 60

# %%
# Initialize router - it will automatically load all restaurants
router = DeliveryRouter("Rinteln, Germany")

# Add delivery address
delivery_address = "6, Bachweg, Rinteln, 31737"
try:
    delivery_location = router.geocoder.geocode(delivery_address)
    driver_position = (delivery_location.latitude, delivery_location.longitude)
    print(f"Delivery location found: {delivery_location.latitude}, {delivery_location.longitude}")
except Exception as e:
    print(f"Error geocoding delivery address: {e}")

# Print all found restaurants
print("\nAll restaurants found in Rinteln:")
# for name, data in router.restaurants.items():
    # print(f"{name}: {data['address']} ({data['type']}, {data['cuisine']})")
print(f"len(router.restaurants.items()) {len(router.restaurants.items())}")
# Create and save map
map_view = router.visualize_map(
    driver_position=driver_position
)

map_view.save('rinteln_all_restaurants_map.html')
# Out:
# Added: Italia (Pferdemarkt 16, Rinteln)
# Added: Ipeks Döneria (Konrad-Adenauer-Straße 34, Rinteln)
# Added: nan (nan nan, Rinteln)
# Added: La Taverna (nan nan, Rinteln)
# Added: Zum Pfingsttor (Pfingsttorstraße 24, Rinteln)
# Added: Burg-Gaststätte (nan nan, Rinteln)
# Added: Da Fabio (Extertalstraße 41, Rinteln)
# Added: Prasuhn's Hofcafé (Landstraße 13, Rinteln)
# Added: Waldgasthaus Homberg (Kleine Heide 9, Rinteln)
# Added: Eiscafé Rialto (Marktplatz 5, Rinteln)
# Added: Klönklause (nan nan, Rinteln)
# Added: Odysseus Grill (Brennerstraße 16, Rinteln)
# Added: Asia Palast (Mühlenstraße 8, Rinteln)
# Added: McDonald's (Konrad-Adenauer-Straße 44, Rinteln)
# Added: Freizeit-Center Schubertweg (Schubertweg 44, Rinteln)
# Added: Hotel Gasthaus Zur Linde (Hauptstraße 30, Rinteln)
# Added: Shang-Hai (Stoevesandtstraße 4, Rinteln)
# Added: Schildkröte (nan nan, Rinteln)
# Added: Pizzeria Rino (Bahnhofsallee 12, Rinteln)
# Added: Bodega Rinteln (nan nan, Rinteln)
# Added: Kuddel's Grillstube (Bahnhofstraße 5A, Rinteln)
# Added: Akropolis - Griechische Spezialitäten (Mühlenstraße 13, Rinteln)
# Added: Café Sinke (Marktplatz 13, Rinteln)
# Added: Azzurro (nan nan, Rinteln)
# Added: Schaumburger Ritter (nan nan, Rinteln)
# Added: Paschenburg (nan nan, Rinteln)
# Added: Pizzeria Corallo (nan nan, Rinteln)
# Added: Imbiss Fleischerei Kaluza (nan nan, Rinteln)
# Added: Bistro GreenBee (Klosterstraße 44, Rinteln)
# Added: Eiscafé Cortina (Klosterstraße 35, Rinteln)
# Added: Antik Cafe Ritter (Extertalstraße 4, Rinteln)
# Added: Salam Döner (Mühlenstraße 10, Rinteln)
# Added: La Fontana Pizza (nan nan, Rinteln)
# Added: Fisch-Pfanne (nan nan, Rinteln)
# Added: Mykonos (nan nan, Rinteln)
# Added: Café Waltraut (nan nan, Rinteln)
# Added: Hofgarten (Am Kloster 1, Rinteln)
# Added: Buffalo Burger (Bahnhofstraße 14, Rinteln)
# Added: Zum Kroaten (nan nan, Rinteln)
# Added: Bistro Miyazaki (Weserstraße 29, Rinteln)
# Added: FIRAT (nan nan, Rinteln)
# Added: Wein Agentur Weinzeichen (Kirchplatz 13, Rinteln)
# Added: Treffpunkt (nan nan, Rinteln)
# Added: Döner Imbiss 27 (nan nan, Rinteln)
# Added: Restaurant Paschenburg (Paschenburg 1, Rinteln)
# Added: nan (nan nan, Rinteln)
# Added: Sorbas (Am Doktorsee 16, Rinteln)
# Added: Eiscafe Venezia (Weserstraße 8, Rinteln)
# Added: Mosquito (Brennerstraße 19, Rinteln)
# Added: Marktwirtschaft (Marktplatz 8, Rinteln)
# Added: MASAY Lounge Shisha Bar (nan nan, Rinteln)
# Added: nan (Weserstraße 11, Rinteln)
# Added: nan (nan nan, Rinteln)
# Added: Klippenturm Gaststätte (nan nan, Rinteln)
# Added: Bodega Beach Bar (nan nan, Rinteln)
# Added: Fliegergaststätte zum Cumulus (Bruchwiesenweg nan, Rinteln)
# Added: Fantasia (nan nan, Rinteln)
# Delivery location found: 52.2052102, 9.0932679
#
# All restaurants found in Rinteln:
# len(router.restaurants.items()) 54

# %%
router = DeliveryRouter(city="Rinteln, Germany")

# Add restaurants with full addresses and increased timeout
restaurants = {
    "Bodega": "31737 Rinteln",
    "Mykonos": "31737 Rinteln",
    "Bodega Beach Bar": "31737 Rinteln",
    "Kuddel's Grillstube": "31737 Rinteln",
    "Pizzeria Corallo": "31737 Rinteln",
    "Da Fabio": "31737 Rinteln"
}

# Add each restaurant and print the results
for name, address in restaurants.items():
    success = router.add_restaurant(name, address)
    print(f"Adding {name}: {'Success' if success else 'Failed'}")

# Add delivery address
delivery_address = "6, Bachweg, Rinteln, 31737"
try:
    delivery_location = router.geocoder.geocode(delivery_address)
    driver_position = (delivery_location.latitude, delivery_location.longitude)
    print(f"Delivery location found: {delivery_location.latitude}, {delivery_location.longitude}")
except Exception as e:
    print(f"Error geocoding delivery address: {e}")
# Out:
# Adding Bodega: Success
# Adding Mykonos: Success
# Adding Bodega Beach Bar: Success
# Adding Kuddel's Grillstube: Success
# Adding Pizzeria Corallo: Success
# Adding Da Fabio: Success
# Delivery location found: 52.2052102, 9.0932679

# %%
# beach_bar_data = router.restaurants["Bodega Beach Bar"]
# destination = (beach_bar_data["lat"], beach_bar_data["lon"])

# route = router.calculate_route_advanced(
#     start_coords=driver_position,
#     end_coords=destination
# )
# # route_map = ox.plot.plot_graph(router.G)
# # ox.plot.plot_graph_route(router.G, route, route_linewidth=6, node_size=0, bgcolor='k')
# print(f"route {route}")
# # Create and save map without route calculation for now
# map_view = router.visualize_map(
#     driver_position=driver_position,
#     route=route
# )
# map_view.save('rinteln_delivery_map.html')

# # Print all successfully geocoded locations
# print("\nStored restaurant locations:")
# for name, data in router.restaurants.items():
#     print(f"{name}: {data['lat']}, {data['lon']}")
